# %% [markdown]
# ### GROUP 10
#
# **PHASE 2 CAPSTONE PROJECT**
#
# **MEMBERS:**
# - Job Cheruyout
# - Eric Miriti
# - Susan Mworia
# - Lydia Mangoa
# - Evans Makau
# - Wambui Kariuki

# %% [markdown]
# ### BUSINESS UNDERSTANDING

# %% [markdown]
# ### Problem Statement
# Our company is launching a new movie studio, inspired by the success of original video content from leading companies. To guide this new venture, we are studying current box office trends to determine the most successful genres and themes. These insights will be turned into actionable recommendations to help the studio create films that will resonate with audiences and perform well in theaters.

# %% [markdown]
# ###**Data Collection**
#
# Data availed from below websites:
#
# Fot TMDB, data scraping was done to get more fields for analysis
#
#
# *   https://www.themoviedb.org/
# *   https://www.imdb.com/

# %% [markdown]
# #### TMDB

# %%
import pandas as pd
import ast
import requests
import time
import sqlite3
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm
from scipy.stats import t
from scipy.stats import ttest_1samp
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# SCRAPING THE TMDB WEBSITE FOR DATA USING API CALLS
file_path = '/content/drive/MyDrive/tmdb.movies.csv.gz'
data = pd.read_csv(file_path)

# TMDB API Key
API_KEY = '1747bacc4f65a1c1db0f28b00f7ec810'
BASE_URL = 'https://api.themoviedb.org/3'

# Function to query TMDB API
def fetch_movie_details(movie_id):
    try:
        # Movie details endpoint
        movie_url = f"{BASE_URL}/movie/{movie_id}?api_key={API_KEY}"
        credits_url = f"{BASE_URL}/movie/{movie_id}/credits?api_key={API_KEY}"

        # Fetch movie details
        movie_response = requests.get(movie_url).json()
        credits_response = requests.get(credits_url).json()

        # Extract required data
        overview = movie_response.get('overview', 'No overview available')
        revenue = movie_response.get('revenue', 'N/A')
        cast = [member['name'] for member in credits_response.get('cast', [])[:5]]  # Top 5 cast members
        director = next(
            (crew['name'] for crew in credits_response.get('crew', []) if crew['job'] == 'Director'),
            'N/A'
        )

        return {
            'Overview': overview,
            'Revenue': revenue,
            'Top Cast': ', '.join(cast),
            'Director': director
        }
    except Exception as e:
        return {
            'Overview': 'Error',
            'Revenue': 'Error',
            'Top Cast': 'Error',
            'Director': 'Error',
            'Error': str(e)
        }

# Add new columns for enriched data
data['Overview'] = None
data['Revenue'] = None
data['Top Cast'] = None
data['Director'] = None

# Fetch data for each movie
for index, row in data.iterrows():
    movie_id = row['id']
    details = fetch_movie_details(movie_id)
    data.at[index, 'Overview'] = details['Overview']
    data.at[index, 'Revenue'] = details['Revenue']
    data.at[index, 'Top Cast'] = details['Top Cast']
    data.at[index, 'Director'] = details['Director']

    print(f"Processed movie ID {movie_id}")  # Progress update
    time.sleep(0.2)  # Respect API rate limits (adjust as needed)

# Save the enriched dataset
output_file = 'enriched_tmdb_movies.csv'
data.to_csv(output_file, index=False)
print(f"Enriched data saved to {output_file}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Processed movie ID 58760
# Processed movie ID 122372
# Processed movie ID 70862
# Processed movie ID 77812
# Processed movie ID 61400
# Processed movie ID 83125
# Processed movie ID 82929
# Processed movie ID 57941
# Processed movie ID 50272
# Processed movie ID 109581
# Processed movie ID 78309
# Processed movie ID 76815
# Processed movie ID 108251
# Processed movie ID 65953
# Processed movie ID 60421
# Processed movie ID 63686
# Processed movie ID 57889
# Processed movie ID 68335
# Processed movie ID 87108
# Processed movie ID 296192
# Processed movie ID 286328
# Processed movie ID 82756
# Processed movie ID 109230
# Processed movie ID 79201
# Processed movie ID 83891
# Processed movie ID 118249
# Processed movie ID 87820
# Processed movie ID 45075
# Processed movie ID 48573
# Processed movie ID 77261
# Processed movie ID 67943
# Processed movie ID 55151
# Processed movie ID 91930
# Processed movie ID 120370
# Processed movie ID 204973
# Processed movie ID 80201
# Processed movie ID 75507
# Processed movie ID 74328
# Processed movie ID 71548
# Processed movie ID 70925
# Processed movie ID 42679
# Processed movie ID 70583
# Processed movie ID 72551
# Processed movie ID 31185
# Processed movie ID 76360
# Processed movie ID 227257
# Processed movie ID 113736
# Processed movie ID 86726
# Processed movie ID 83754
# Processed movie ID 150065
# Processed movie ID 83938
# Processed movie ID 53505
# Processed movie ID 287940
# Processed movie ID 52413
# Processed movie ID 48417
# Processed movie ID 63447
# Processed movie ID 55248
# Processed movie ID 58679
# Processed movie ID 85944
# Processed movie ID 77444
# Processed movie ID 78224
# Processed movie ID 61294
# Processed movie ID 65892
# Processed movie ID 88752
# Processed movie ID 62069
# Processed movie ID 57400
# Processed movie ID 76175
# Processed movie ID 84449
# Processed movie ID 60098
# Processed movie ID 82685
# Processed movie ID 129798
# Processed movie ID 58959
# Processed movie ID 85729
# Processed movie ID 145312
# Processed movie ID 75862
# Processed movie ID 58448
# Processed movie ID 70878
# Processed movie ID 79919
# Processed movie ID 63555
# Processed movie ID 42916
# Processed movie ID 81670
# Processed movie ID 67655
# Processed movie ID 72951
# Processed movie ID 57518
# Processed movie ID 65696
# Processed movie ID 83330
# Processed movie ID 81421
# Processed movie ID 82510
# Processed movie ID 56965
# Processed movie ID 78220
# Processed movie ID 63326
# Processed movie ID 86075
# Processed movie ID 50081
# Processed movie ID 80583
# Processed movie ID 44246
# Processed movie ID 82708
# Processed movie ID 222664
# Processed movie ID 129790
# Processed movie ID 64687
# Processed movie ID 77715
# Processed movie ID 72049
# Processed movie ID 80276
# Processed movie ID 85441
# Processed movie ID 90756
# Processed movie ID 63142
# Processed movie ID 101852
# Processed movie ID 77186
# Processed movie ID 75107
# Processed movie ID 118354
# Processed movie ID 75442
# Processed movie ID 86549
# Processed movie ID 58258
# Processed movie ID 129120
# Processed movie ID 58718
# Processed movie ID 80337
# Processed movie ID 65214
# Processed movie ID 53101
# Processed movie ID 82492
# Processed movie ID 74310
# Processed movie ID 66767
# Processed movie ID 82620
# Processed movie ID 65345
# Processed movie ID 86709
# Processed movie ID 83192
# Processed movie ID 169730
# Processed movie ID 85593
# Processed movie ID 61014
# Processed movie ID 87313
# Processed movie ID 70845
# Processed movie ID 137475
# Processed movie ID 89593
# Processed movie ID 79987
# Processed movie ID 61038
# Processed movie ID 76635
# Processed movie ID 57510
# Processed movie ID 57393
# Processed movie ID 119197
# Processed movie ID 98932
# Processed movie ID 116853
# Processed movie ID 16516
# Processed movie ID 103516
# Processed movie ID 70808
# Processed movie ID 73829
# Processed movie ID 58792
# Processed movie ID 71482
# Processed movie ID 107753
# Processed movie ID 76800
# Processed movie ID 68202
# Processed movie ID 62116
# Processed movie ID 79976
# Processed movie ID 83473
# Processed movie ID 67958
# Processed movie ID 61346
# Processed movie ID 71326
# Processed movie ID 44160
# Processed movie ID 51490
# Processed movie ID 47845
# Processed movie ID 105945
# Processed movie ID 77240
# Processed movie ID 80299
# Processed movie ID 37472
# Processed movie ID 69794
# Processed movie ID 87425
# Processed movie ID 55998
# Processed movie ID 99581
# Processed movie ID 95435
# Processed movie ID 78339
# Processed movie ID 324213
# Processed movie ID 78555
# Processed movie ID 81420
# Processed movie ID 71830
# Processed movie ID 70692
# Processed movie ID 52475
# Processed movie ID 63144
# Processed movie ID 50493
# Processed movie ID 81527
# Processed movie ID 89403
# Processed movie ID 26864
# Processed movie ID 42707
# Processed movie ID 79582
# Processed movie ID 50119
# Processed movie ID 83403
# Processed movie ID 77485
# Processed movie ID 81694
# Processed movie ID 85807
# Processed movie ID 123928
# Processed movie ID 67273
# Processed movie ID 84520
# Processed movie ID 81179
# Processed movie ID 79042
# Processed movie ID 335642
# Processed movie ID 88057
# Processed movie ID 83728
# Processed movie ID 192690
# Processed movie ID 74406
# Processed movie ID 83732
# Processed movie ID 54897
# Processed movie ID 59728
# Processed movie ID 81298
# Processed movie ID 82686
# Processed movie ID 151866
# Processed movie ID 83388
# Processed movie ID 81185
# Processed movie ID 53925
# Processed movie ID 56171
# Processed movie ID 82655
# Processed movie ID 84942
# Processed movie ID 78509
# Processed movie ID 60678
# Processed movie ID 54100
# Processed movie ID 87018
# Processed movie ID 217292
# Processed movie ID 87311
# Processed movie ID 81539
# Processed movie ID 72843
# Processed movie ID 70669
# Processed movie ID 51497
# Processed movie ID 74549
# Processed movie ID 329841
# Processed movie ID 129611
# Processed movie ID 57207
# Processed movie ID 71285
# Processed movie ID 60740
# Processed movie ID 81330
# Processed movie ID 63297
# Processed movie ID 82259
# Processed movie ID 57448
# Processed movie ID 98549
# Processed movie ID 114168
# Processed movie ID 329243
# Processed movie ID 60977
# Processed movie ID 70876
# Processed movie ID 55190
# Processed movie ID 68878
# Processed movie ID 60189
# Processed movie ID 61107
# Processed movie ID 86841
# Processed movie ID 85348
# Processed movie ID 66794
# Processed movie ID 66605
# Processed movie ID 77551
# Processed movie ID 58884
# Processed movie ID 119677
# Processed movie ID 107315
# Processed movie ID 58221
# Processed movie ID 60981
# Processed movie ID 55093
# Processed movie ID 69097
# Processed movie ID 79557
# Processed movie ID 96534
# Processed movie ID 85860
# Processed movie ID 75421
# Processed movie ID 46106
# Processed movie ID 58887
# Processed movie ID 231384
# Processed movie ID 94042
# Processed movie ID 84154
# Processed movie ID 65347
# Processed movie ID 100825
# Processed movie ID 141418
# Processed movie ID 72766
# Processed movie ID 75654
# Processed movie ID 156019
# Processed movie ID 69396
# Processed movie ID 45347
# Processed movie ID 59430
# Processed movie ID 53338
# Processed movie ID 97191
# Processed movie ID 70768
# Processed movie ID 79554
# Processed movie ID 73474
# Processed movie ID 54534
# Processed movie ID 95192
# Processed movie ID 63147
# Processed movie ID 75282
# Processed movie ID 169721
# Processed movie ID 51450
# Processed movie ID 90232
# Processed movie ID 62425
# Processed movie ID 64004
# Processed movie ID 91926
# Processed movie ID 136972
# Processed movie ID 108855
# Processed movie ID 68639
# Processed movie ID 106541
# Processed movie ID 75803
# Processed movie ID 82479
# Processed movie ID 62976
# Processed movie ID 106493
# Processed movie ID 58891
# Processed movie ID 123969
# Processed movie ID 263963
# Processed movie ID 61613
# Processed movie ID 63045
# Processed movie ID 250275
# Processed movie ID 169068
# Processed movie ID 60233
# Processed movie ID 70863
# Processed movie ID 89883
# Processed movie ID 78332
# Processed movie ID 54358
# Processed movie ID 326262
# Processed movie ID 77957
# Processed movie ID 145099
# Processed movie ID 61539
# Processed movie ID 63472
# Processed movie ID 81434
# Processed movie ID 78323
# Processed movie ID 57487
# Processed movie ID 116532
# Processed movie ID 79890
# Processed movie ID 60164
# Processed movie ID 63143
# Processed movie ID 95524
# Processed movie ID 68200
# Processed movie ID 74943
# Processed movie ID 77171
# Processed movie ID 79580
# Processed movie ID 98627
# Processed movie ID 63736
# Processed movie ID 116272
# Processed movie ID 44008
# Processed movie ID 66925
# Processed movie ID 74877
# Processed movie ID 94265
# Processed movie ID 71070
# Processed movie ID 120055
# Processed movie ID 79906
# Processed movie ID 85312
# Processed movie ID 81576
# Processed movie ID 85657
# Processed movie ID 148888
# Processed movie ID 76164
# Processed movie ID 112016
# Processed movie ID 57573
# Processed movie ID 97481
# Processed movie ID 226897
# Processed movie ID 83583
# Processed movie ID 39458
# Processed movie ID 71900
# Processed movie ID 78807
# Processed movie ID 176589
# Processed movie ID 77586
# Processed movie ID 79475
# Processed movie ID 185564
# Processed movie ID 78226
# Processed movie ID 84924
# Processed movie ID 40248
# Processed movie ID 63367
# Processed movie ID 81626
# Processed movie ID 98197
# Processed movie ID 102640
# Processed movie ID 79159
# Processed movie ID 145186
# Processed movie ID 71905
# Processed movie ID 230652
# Processed movie ID 77299
# Processed movie ID 101766
# Processed movie ID 55680
# Processed movie ID 67328
# Processed movie ID 82666
# Processed movie ID 95761
# Processed movie ID 289097
# Processed movie ID 59266
# Processed movie ID 51548
# Processed movie ID 82466
# Processed movie ID 88508
# Processed movie ID 81619
# Processed movie ID 228550
# Processed movie ID 62522
# Processed movie ID 65992
# Processed movie ID 44878
# Processed movie ID 263768
# Processed movie ID 80539
# Processed movie ID 76127
# Processed movie ID 83373
# Processed movie ID 56440
# Processed movie ID 54353
# Processed movie ID 56537
# Processed movie ID 80170
# Processed movie ID 118397
# Processed movie ID 76226
# Processed movie ID 168633
# Processed movie ID 68384
# Processed movie ID 180607
# Processed movie ID 83092
# Processed movie ID 92968
# Processed movie ID 71394
# Processed movie ID 166752
# Processed movie ID 92850
# Processed movie ID 77585
# Processed movie ID 86328
# Processed movie ID 71950
# Processed movie ID 81623
# Processed movie ID 61533
# Processed movie ID 66211
# Processed movie ID 78192
# Processed movie ID 105962
# Processed movie ID 56761
# Processed movie ID 60775
# Processed movie ID 99279
# Processed movie ID 131389
# Processed movie ID 133196
# Processed movie ID 243279
# Processed movie ID 93872
# Processed movie ID 44096
# Processed movie ID 76947
# Processed movie ID 318666
# Processed movie ID 117546
# Processed movie ID 70576
# Processed movie ID 86517
# Processed movie ID 77185
# Processed movie ID 62219
# Processed movie ID 108354
# Processed movie ID 80147
# Processed movie ID 55003
# Processed movie ID 79926
# Processed movie ID 91680
# Processed movie ID 16726
# Processed movie ID 78083
# Processed movie ID 84267
# Processed movie ID 66470
# Processed movie ID 79010
# Processed movie ID 81484
# Processed movie ID 60170
# Processed movie ID 196967
# Processed movie ID 70425
# Processed movie ID 74561
# Processed movie ID 179404
# Processed movie ID 89461
# Processed movie ID 80242
# Processed movie ID 169510
# Processed movie ID 56441
# Processed movie ID 53104
# Processed movie ID 78187
# Processed movie ID 376845
# Processed movie ID 83907
# Processed movie ID 73099
# Processed movie ID 258984
# Processed movie ID 53054
# Processed movie ID 63743
# Processed movie ID 198207
# Processed movie ID 377765
# Processed movie ID 63006
# Processed movie ID 68184
# Processed movie ID 105545
# Processed movie ID 63946
# Processed movie ID 79780
# Processed movie ID 73669
# Processed movie ID 109455
# Processed movie ID 164052
# Processed movie ID 119087
# Processed movie ID 85423
# Processed movie ID 96495
# Processed movie ID 152848
# Processed movie ID 86577
# Processed movie ID 51507
# Processed movie ID 88537
# Processed movie ID 115374
# Processed movie ID 106288
# Processed movie ID 78184
# Processed movie ID 101952
# Processed movie ID 85493
# Processed movie ID 64810
# Processed movie ID 49538
# Processed movie ID 111352
# Processed movie ID 75191
# Processed movie ID 246252
# Processed movie ID 89432
# Processed movie ID 75745
# Processed movie ID 366214
# Processed movie ID 104109
# Processed movie ID 102363
# Processed movie ID 63140
# Processed movie ID 77874
# Processed movie ID 268956
# Processed movie ID 251030
# Processed movie ID 82916
# Processed movie ID 28565
# Processed movie ID 307124
# Processed movie ID 145054
# Processed movie ID 79327
# Processed movie ID 93897
# Processed movie ID 134683
# Processed movie ID 76398
# Processed movie ID 71813
# Processed movie ID 57469
# Processed movie ID 81976
# Processed movie ID 513138
# Processed movie ID 249131
# Processed movie ID 104250
# Processed movie ID 94822
# Processed movie ID 85818
# Processed movie ID 323867
# Processed movie ID 113678
# Processed movie ID 86495
# Processed movie ID 80121
# Processed movie ID 87241
# Processed movie ID 46060
# Processed movie ID 58862
# Processed movie ID 135465
# Processed movie ID 127728
# Processed movie ID 87332
# Processed movie ID 81215
# Processed movie ID 79056
# Processed movie ID 113961
# Processed movie ID 73335
# Processed movie ID 205142
# Processed movie ID 174400
# Processed movie ID 142540
# Processed movie ID 75949
# Processed movie ID 88745
# Processed movie ID 108235
# Processed movie ID 170915
# Processed movie ID 91628
# Processed movie ID 70264
# Processed movie ID 296839
# Processed movie ID 66774
# Processed movie ID 56891
# Processed movie ID 105932
# Processed movie ID 81581
# Processed movie ID 74147
# Processed movie ID 142039
# Processed movie ID 82382
# Processed movie ID 128517
# Processed movie ID 119086
# Processed movie ID 104194
# Processed movie ID 81578
# Processed movie ID 70829
# Processed movie ID 77083
# Processed movie ID 83278
# Processed movie ID 69803
# Processed movie ID 240896
# Processed movie ID 46256
# Processed movie ID 220980
# Processed movie ID 75576
# Processed movie ID 336598
# Processed movie ID 160494
# Processed movie ID 140781
# Processed movie ID 76037
# Processed movie ID 266808
# Processed movie ID 80503
# Processed movie ID 77440
# Processed movie ID 72246
# Processed movie ID 58692
# Processed movie ID 61948
# Processed movie ID 276570
# Processed movie ID 122202
# Processed movie ID 65122
# Processed movie ID 64645
# Processed movie ID 173931
# Processed movie ID 78147
# Processed movie ID 56603
# Processed movie ID 419628
# Processed movie ID 111166
# Processed movie ID 116005
# Processed movie ID 322519
# Processed movie ID 76354
# Processed movie ID 34685
# Processed movie ID 94334
# Processed movie ID 316437
# Processed movie ID 81236
# Processed movie ID 85543
# Processed movie ID 134147
# Processed movie ID 375247
# Processed movie ID 78403
# Processed movie ID 143192
# Processed movie ID 44898
# Processed movie ID 295321
# Processed movie ID 113985
# Processed movie ID 96739
# Processed movie ID 80263
# Processed movie ID 55839
# Processed movie ID 57395
# Processed movie ID 97132
# Processed movie ID 75785
# Processed movie ID 223902
# Processed movie ID 75604
# Processed movie ID 93383
# Processed movie ID 70283
# Processed movie ID 135678
# Processed movie ID 79779
# Processed movie ID 54379
# Processed movie ID 104738
# Processed movie ID 102420
# Processed movie ID 64282
# Processed movie ID 82932
# Processed movie ID 48487
# Processed movie ID 70197
# Processed movie ID 81202
# Processed movie ID 89827
# Processed movie ID 249110
# Processed movie ID 79579
# Processed movie ID 72440
# Processed movie ID 79574
# Processed movie ID 78646
# Processed movie ID 82911
# Processed movie ID 74830
# Processed movie ID 84391
# Processed movie ID 76142
# Processed movie ID 76165
# Processed movie ID 375384
# Processed movie ID 307903
# Processed movie ID 126223
# Processed movie ID 79007
# Processed movie ID 80618
# Processed movie ID 84583
# Processed movie ID 77821
# Processed movie ID 182237
# Processed movie ID 86728
# Processed movie ID 93904
# Processed movie ID 81707
# Processed movie ID 129175
# Processed movie ID 178002
# Processed movie ID 121800
# Processed movie ID 80161
# Processed movie ID 61408
# Processed movie ID 313757
# Processed movie ID 97015
# Processed movie ID 122466
# Processed movie ID 333918
# Processed movie ID 63094
# Processed movie ID 62668
# Processed movie ID 136558
# Processed movie ID 100212
# Processed movie ID 246115
# Processed movie ID 207356
# Processed movie ID 79728
# Processed movie ID 187799
# Processed movie ID 58494
# Processed movie ID 82252
# Processed movie ID 78446
# Processed movie ID 91322
# Processed movie ID 77880
# Processed movie ID 79721
# Processed movie ID 116319
# Processed movie ID 82123
# Processed movie ID 52643
# Processed movie ID 81345
# Processed movie ID 60819
# Processed movie ID 83927
# Processed movie ID 127803
# Processed movie ID 75441
# Processed movie ID 107869
# Processed movie ID 79611
# Processed movie ID 146946
# Processed movie ID 262069
# Processed movie ID 57701
# Processed movie ID 48837
# Processed movie ID 78056
# Processed movie ID 103707
# Processed movie ID 67903
# Processed movie ID 188089
# Processed movie ID 117944
# Processed movie ID 270169
# Processed movie ID 63852
# Processed movie ID 61233
# Processed movie ID 76778
# Processed movie ID 314194
# Processed movie ID 59805
# Processed movie ID 141976
# Processed movie ID 97864
# Processed movie ID 61198
# Processed movie ID 71443
# Processed movie ID 196317
# Processed movie ID 78288
# Processed movie ID 243599
# Processed movie ID 138959
# Processed movie ID 65803
# Processed movie ID 82817
# Processed movie ID 80041
# Processed movie ID 112024
# Processed movie ID 111964
# Processed movie ID 78098
# Processed movie ID 80169
# Processed movie ID 89524
# Processed movie ID 75469
# Processed movie ID 79999
# Processed movie ID 68948
# Processed movie ID 282275
# Processed movie ID 82115
# Processed movie ID 74424
# Processed movie ID 213270
# Processed movie ID 69877
# Processed movie ID 48751
# Processed movie ID 116898
# Processed movie ID 82935
# Processed movie ID 103391
# Processed movie ID 290529
# Processed movie ID 57955
# Processed movie ID 69639
# Processed movie ID 144271
# Processed movie ID 96933
# Processed movie ID 71733
# Processed movie ID 62777
# Processed movie ID 94331
# Processed movie ID 38415
# Processed movie ID 124887
# Processed movie ID 212767
# Processed movie ID 63494
# Processed movie ID 98065
# Processed movie ID 74457
# Processed movie ID 493549
# Processed movie ID 180604
# Processed movie ID 103668
# Processed movie ID 129929
# Processed movie ID 116514
# Processed movie ID 82640
# Processed movie ID 77092
# Processed movie ID 62685
# Processed movie ID 116165
# Processed movie ID 41483
# Processed movie ID 79700
# Processed movie ID 127880
# Processed movie ID 68241
# Processed movie ID 67723
# Processed movie ID 69333
# Processed movie ID 167670
# Processed movie ID 96888
# Processed movie ID 74546
# Processed movie ID 137896
# Processed movie ID 77884
# Processed movie ID 143083
# Processed movie ID 266588
# Processed movie ID 108917
# Processed movie ID 79462
# Processed movie ID 218553
# Processed movie ID 147923
# Processed movie ID 118622
# Processed movie ID 414278
# Processed movie ID 76234
# Processed movie ID 109236
# Processed movie ID 66025
# Processed movie ID 75000
# Processed movie ID 64836
# Processed movie ID 307732
# Processed movie ID 106294
# Processed movie ID 85989
# Processed movie ID 86652
# Processed movie ID 140846
# Processed movie ID 118988
# Processed movie ID 90873
# Processed movie ID 73361
# Processed movie ID 102931
# Processed movie ID 171363
# Processed movie ID 78397
# Processed movie ID 36974
# Processed movie ID 311666
# Processed movie ID 82688
# Processed movie ID 95807
# Processed movie ID 95538
# Processed movie ID 80301
# Processed movie ID 67619
# Processed movie ID 53358
# Processed movie ID 79536
# Processed movie ID 57211
# Processed movie ID 102116
# Processed movie ID 81438
# Processed movie ID 86723
# Processed movie ID 605408
# Processed movie ID 61372
# Processed movie ID 210892
# Processed movie ID 107872
# Processed movie ID 185248
# Processed movie ID 192483
# Processed movie ID 61263
# Processed movie ID 77439
# Processed movie ID 212927
# Processed movie ID 75322
# Processed movie ID 61854
# Processed movie ID 444633
# Processed movie ID 209523
# Processed movie ID 91312
# Processed movie ID 311218
# Processed movie ID 77881
# Processed movie ID 197302
# Processed movie ID 103322
# Processed movie ID 79708
# Processed movie ID 116735
# Processed movie ID 57503
# Processed movie ID 143193
# Processed movie ID 45244
# Processed movie ID 369481
# Processed movie ID 85905
# Processed movie ID 83093
# Processed movie ID 73574
# Processed movie ID 79965
# Processed movie ID 65822
# Processed movie ID 101953
# Processed movie ID 141867
# Processed movie ID 75149
# Processed movie ID 90322
# Processed movie ID 80603
# Processed movie ID 84280
# Processed movie ID 108718
# Processed movie ID 85819
# Processed movie ID 67908
# Processed movie ID 81212
# Processed movie ID 401224
# Processed movie ID 53437
# Processed movie ID 85025
# Processed movie ID 82909
# Processed movie ID 373929
# Processed movie ID 79640
# Processed movie ID 109976
# Processed movie ID 399197
# Processed movie ID 294105
# Processed movie ID 58194
# Processed movie ID 175122
# Processed movie ID 259086
# Processed movie ID 124330
# Processed movie ID 80753
# Processed movie ID 348536
# Processed movie ID 185331
# Processed movie ID 220854
# Processed movie ID 129057
# Processed movie ID 223308
# Processed movie ID 157162
# Processed movie ID 87098
# Processed movie ID 66624
# Processed movie ID 78709
# Processed movie ID 97429
# Processed movie ID 81969
# Processed movie ID 81961
# Processed movie ID 91466
# Processed movie ID 112238
# Processed movie ID 299225
# Processed movie ID 73941
# Processed movie ID 329212
# Processed movie ID 67117
# Processed movie ID 54799
# Processed movie ID 272885
# Processed movie ID 91352
# Processed movie ID 164183
# Processed movie ID 80024
# Processed movie ID 53436
# Processed movie ID 98554
# Processed movie ID 135682
# Processed movie ID 57697
# Processed movie ID 556516
# Processed movie ID 372135
# Processed movie ID 80210
# Processed movie ID 91927
# Processed movie ID 168658
# Processed movie ID 83040
# Processed movie ID 377096
# Processed movie ID 74253
# Processed movie ID 70071
# Processed movie ID 395639
# Processed movie ID 336881
# Processed movie ID 168911
# Processed movie ID 377610
# Processed movie ID 161427
# Processed movie ID 57599
# Processed movie ID 291616
# Processed movie ID 99180
# Processed movie ID 83478
# Processed movie ID 352826
# Processed movie ID 431241
# Processed movie ID 412416
# Processed movie ID 76318
# Processed movie ID 357170
# Processed movie ID 335878
# Processed movie ID 123279
# Processed movie ID 89196
# Processed movie ID 207345
# Processed movie ID 193139
# Processed movie ID 125472
# Processed movie ID 103812
# Processed movie ID 263876
# Processed movie ID 57817
# Processed movie ID 309780
# Processed movie ID 99969
# Processed movie ID 87593
# Processed movie ID 348161
# Processed movie ID 460255
# Processed movie ID 122208
# Processed movie ID 62428
# Processed movie ID 220493
# Processed movie ID 46104
# Processed movie ID 68387
# Processed movie ID 127747
# Processed movie ID 208572
# Processed movie ID 87849
# Processed movie ID 133953
# Processed movie ID 57172
# Processed movie ID 96525
# Processed movie ID 65016
# Processed movie ID 451820
# Processed movie ID 278083
# Processed movie ID 256858
# Processed movie ID 495030
# Processed movie ID 156004
# Processed movie ID 155113
# Processed movie ID 53328
# Processed movie ID 287157
# Processed movie ID 132372
# Processed movie ID 113201
# Processed movie ID 110095
# Processed movie ID 63138
# Processed movie ID 171270
# Processed movie ID 84134
# Processed movie ID 416669
# Processed movie ID 369551
# Processed movie ID 202152
# Processed movie ID 181356
# Processed movie ID 135472
# Processed movie ID 109293
# Processed movie ID 105561
# Processed movie ID 305346
# Processed movie ID 222228
# Processed movie ID 106855
# Processed movie ID 260104
# Processed movie ID 179809
# Processed movie ID 42747
# Processed movie ID 82331
# Processed movie ID 459979
# Processed movie ID 381427
# Processed movie ID 265496
# Processed movie ID 261179
# Processed movie ID 257000
# Processed movie ID 253437
# Processed movie ID 242617
# Processed movie ID 234343
# Processed movie ID 88521
# Processed movie ID 65714
# Processed movie ID 60892
# Processed movie ID 132858
# Processed movie ID 226056
# Processed movie ID 107751
# Processed movie ID 115559
# Processed movie ID 37630
# Processed movie ID 119489
# Processed movie ID 83474
# Processed movie ID 100138
# Processed movie ID 72913
# Processed movie ID 63683
# Processed movie ID 305566
# Processed movie ID 82102
# Processed movie ID 153533
# Processed movie ID 89841
# Processed movie ID 168405
# Processed movie ID 81620
# Processed movie ID 223307
# Processed movie ID 187796
# Processed movie ID 76518
# Processed movie ID 128693
# Processed movie ID 226052
# Processed movie ID 155577
# Processed movie ID 140218
# Processed movie ID 100095
# Processed movie ID 274343
# Processed movie ID 134335
# Processed movie ID 79819
# Processed movie ID 208160
# Processed movie ID 85874
# Processed movie ID 75680
# Processed movie ID 106339
# Processed movie ID 83724
# Processed movie ID 410534
# Processed movie ID 565299
# Processed movie ID 369203
# Processed movie ID 58088
# Processed movie ID 70112
# Processed movie ID 293743
# Processed movie ID 86821
# Processed movie ID 70833
# Processed movie ID 415428
# Processed movie ID 170792
# Processed movie ID 76922
# Processed movie ID 85303
# Processed movie ID 113726
# Processed movie ID 57019
# Processed movie ID 198996
# Processed movie ID 74537
# Processed movie ID 65344
# Processed movie ID 214857
# Processed movie ID 80043
# Processed movie ID 481352
# Processed movie ID 110204
# Processed movie ID 116065
# Processed movie ID 210992
# Processed movie ID 186071
# Processed movie ID 301368
# Processed movie ID 59900
# Processed movie ID 77910
# Processed movie ID 61601
# Processed movie ID 54598
# Processed movie ID 83242
# Processed movie ID 68333
# Processed movie ID 352359
# Processed movie ID 108153
# Processed movie ID 163250
# Processed movie ID 60715
# Processed movie ID 172854
# Processed movie ID 226992
# Processed movie ID 86815
# Processed movie ID 109511
# Processed movie ID 68253
# Processed movie ID 73875
# Processed movie ID 81830
# Processed movie ID 75354
# Processed movie ID 57553
# Processed movie ID 144860
# Processed movie ID 168771
# Processed movie ID 190946
# Processed movie ID 103661
# Processed movie ID 54101
# Processed movie ID 282034
# Processed movie ID 85445
# Processed movie ID 110553
# Processed movie ID 77515
# Processed movie ID 86380
# Processed movie ID 116437
# Processed movie ID 154205
# Processed movie ID 98870
# Processed movie ID 331051
# Processed movie ID 146315
# Processed movie ID 275355
# Processed movie ID 74321
# Processed movie ID 198279
# Processed movie ID 58730
# Processed movie ID 84738
# Processed movie ID 58960
# Processed movie ID 502030
# Processed movie ID 276871
# Processed movie ID 186600
# Processed movie ID 68662
# Processed movie ID 69884
# Processed movie ID 145210
# Processed movie ID 110677
# Processed movie ID 109437
# Processed movie ID 392284
# Processed movie ID 105037
# Processed movie ID 154210
# Processed movie ID 78244
# Processed movie ID 68613
# Processed movie ID 103815
# Processed movie ID 63001
# Processed movie ID 260482
# Processed movie ID 375317
# Processed movie ID 79820
# Processed movie ID 67081
# Processed movie ID 78814
# Processed movie ID 83734
# Processed movie ID 86627
# Processed movie ID 239650
# Processed movie ID 60063
# Processed movie ID 73960
# Processed movie ID 70758
# Processed movie ID 63687
# Processed movie ID 311159
# Processed movie ID 227048
# Processed movie ID 121245
# Processed movie ID 71155
# Processed movie ID 156620
# Processed movie ID 128571
# Processed movie ID 79627
# Processed movie ID 86410
# Processed movie ID 75863
# Processed movie ID 419631
# Processed movie ID 103514
# Processed movie ID 145037
# Processed movie ID 111859
# Processed movie ID 137484
# Processed movie ID 65767
# Processed movie ID 296459
# Processed movie ID 109585
# Processed movie ID 165153
# Processed movie ID 495894
# Processed movie ID 143871
# Processed movie ID 420071
# Processed movie ID 73581
# Processed movie ID 74327
# Processed movie ID 41840
# Processed movie ID 433336
# Processed movie ID 498860
# Processed movie ID 211894
# Processed movie ID 158189
# Processed movie ID 108727
# Processed movie ID 84181
# Processed movie ID 72703
# Processed movie ID 105478
# Processed movie ID 77935
# Processed movie ID 333930
# Processed movie ID 400953
# Processed movie ID 82673
# Processed movie ID 79644
# Processed movie ID 76795
# Processed movie ID 134406
# Processed movie ID 93053
# Processed movie ID 238529
# Processed movie ID 187288
# Processed movie ID 130712
# Processed movie ID 82689
# Processed movie ID 294371
# Processed movie ID 266462
# Processed movie ID 135712
# Processed movie ID 92626
# Processed movie ID 75559
# Processed movie ID 69963
# Processed movie ID 285224
# Processed movie ID 281296
# Processed movie ID 121104
# Processed movie ID 76042
# Processed movie ID 328038
# Processed movie ID 129539
# Processed movie ID 82110
# Processed movie ID 214703
# Processed movie ID 207517
# Processed movie ID 102312
# Processed movie ID 82707
# Processed movie ID 205623
# Processed movie ID 76199
# Processed movie ID 63890
# Processed movie ID 248859
# Processed movie ID 465739
# Processed movie ID 69878
# Processed movie ID 71175
# Processed movie ID 75846
# Processed movie ID 115448
# Processed movie ID 76239
# Processed movie ID 114588
# Processed movie ID 313903
# Processed movie ID 240159
# Processed movie ID 275669
# Processed movie ID 155294
# Processed movie ID 323922
# Processed movie ID 165274
# Processed movie ID 111957
# Processed movie ID 537876
# Processed movie ID 511945
# Processed movie ID 403303
# Processed movie ID 325774
# Processed movie ID 252506
# Processed movie ID 242620
# Processed movie ID 166662
# Processed movie ID 160122
# Processed movie ID 104213
# Processed movie ID 601429
# Processed movie ID 490285
# Processed movie ID 376996
# Processed movie ID 292183
# Processed movie ID 145318
# Processed movie ID 100608
# Processed movie ID 414060
# Processed movie ID 406437
# Processed movie ID 126782
# Processed movie ID 82676
# Processed movie ID 81579
# Processed movie ID 464751
# Processed movie ID 403739
# Processed movie ID 381782
# Processed movie ID 315389
# Processed movie ID 288624
# Processed movie ID 274023
# Processed movie ID 226280
# Processed movie ID 124998
# Processed movie ID 101632
# Processed movie ID 532683
# Processed movie ID 453454
# Processed movie ID 399830
# Processed movie ID 379688
# Processed movie ID 323375
# Processed movie ID 301713
# Processed movie ID 180988
# Processed movie ID 77011
# Processed movie ID 70834
# Processed movie ID 59588
# Processed movie ID 537401
# Processed movie ID 508796
# Processed movie ID 467930
# Processed movie ID 428024
# Processed movie ID 378962
# Processed movie ID 300035
# Processed movie ID 292051
# Processed movie ID 262392
# Processed movie ID 178227
# Processed movie ID 146898
# Processed movie ID 82677
# Processed movie ID 81776
# Processed movie ID 77876
# Processed movie ID 343751
# Processed movie ID 434679
# Processed movie ID 294160
# Processed movie ID 226459
# Processed movie ID 209806
# Processed movie ID 545433
# Processed movie ID 270993
# Processed movie ID 79470
# Processed movie ID 135713
# Processed movie ID 385637
# Processed movie ID 205818
# Processed movie ID 123542
# Processed movie ID 117963
# Processed movie ID 97265
# Processed movie ID 74255
# Processed movie ID 101168
# Processed movie ID 567178
# Processed movie ID 345573
# Processed movie ID 328141
# Processed movie ID 210305
# Processed movie ID 97095
# Processed movie ID 128398
# Processed movie ID 123174
# Processed movie ID 501118
# Processed movie ID 141747
# Processed movie ID 89194
# Processed movie ID 50024
# Processed movie ID 317875
# Processed movie ID 399196
# Processed movie ID 338486
# Processed movie ID 157765
# Processed movie ID 120752
# Processed movie ID 114708
# Processed movie ID 69863
# Processed movie ID 317639
# Processed movie ID 280171
# Processed movie ID 122582
# Processed movie ID 119172
# Processed movie ID 62196
# Processed movie ID 154352
# Processed movie ID 99762
# Processed movie ID 602984
# Processed movie ID 552110
# Processed movie ID 543511
# Processed movie ID 526456
# Processed movie ID 509912
# Processed movie ID 485834
# Processed movie ID 455240
# Processed movie ID 452916
# Processed movie ID 431245
# Processed movie ID 430779
# Processed movie ID 430221
# Processed movie ID 405549
# Processed movie ID 402853
# Processed movie ID 385559
# Processed movie ID 365059
# Processed movie ID 347236
# Processed movie ID 336718
# Processed movie ID 332937
# Processed movie ID 326628
# Processed movie ID 314870
# Processed movie ID 310335
# Processed movie ID 297321
# Processed movie ID 251441
# Processed movie ID 239063
# Processed movie ID 225104
# Processed movie ID 213632
# Processed movie ID 210794
# Processed movie ID 201868
# Processed movie ID 200719
# Processed movie ID 199801
# Processed movie ID 192454
# Processed movie ID 189401
# Processed movie ID 141495
# Processed movie ID 141274
# Processed movie ID 140970
# Processed movie ID 139970
# Processed movie ID 136310
# Processed movie ID 135101
# Processed movie ID 134782
# Processed movie ID 129058
# Processed movie ID 122350
# Processed movie ID 107768
# Processed movie ID 94762
# Processed movie ID 88746
# Processed movie ID 81663
# Processed movie ID 80848
# Processed movie ID 78043
# Processed movie ID 75849
# Processed movie ID 74762
# Processed movie ID 74292
# Processed movie ID 74196
# Processed movie ID 70565
# Processed movie ID 70427
# Processed movie ID 69314
# Processed movie ID 61030
# Processed movie ID 55527
# Processed movie ID 520607
# Processed movie ID 520590
# Processed movie ID 397960
# Processed movie ID 395283
# Processed movie ID 392906
# Processed movie ID 278338
# Processed movie ID 232484
# Processed movie ID 219874
# Processed movie ID 100839
# Processed movie ID 520613
# Processed movie ID 332626
# Processed movie ID 433342
# Processed movie ID 421818
# Processed movie ID 409172
# Processed movie ID 407874
# Processed movie ID 353247
# Processed movie ID 301069
# Processed movie ID 298014
# Processed movie ID 262896
# Processed movie ID 235255
# Processed movie ID 198342
# Processed movie ID 137270
# Processed movie ID 104542
# Processed movie ID 101617
# Processed movie ID 67076
# Processed movie ID 45703
# Processed movie ID 307381
# Processed movie ID 154414
# Processed movie ID 322864
# Processed movie ID 278833
# Processed movie ID 204096
# Processed movie ID 188716
# Processed movie ID 181563
# Processed movie ID 177048
# Processed movie ID 172764
# Processed movie ID 167888
# Processed movie ID 138950
# Processed movie ID 137083
# Processed movie ID 131655
# Processed movie ID 80308
# Processed movie ID 72393
# Processed movie ID 520599
# Processed movie ID 89153
# Processed movie ID 253694
# Processed movie ID 132709
# Processed movie ID 99370
# Processed movie ID 87389
# Processed movie ID 208982
# Processed movie ID 510653
# Processed movie ID 504421
# Processed movie ID 498942
# Processed movie ID 464276
# Processed movie ID 450333
# Processed movie ID 449725
# Processed movie ID 449723
# Processed movie ID 449719
# Processed movie ID 445669
# Processed movie ID 428934
# Processed movie ID 419468
# Processed movie ID 416870
# Processed movie ID 407001
# Processed movie ID 403298
# Processed movie ID 377499
# Processed movie ID 372197
# Processed movie ID 358256
# Processed movie ID 356753
# Processed movie ID 353862
# Processed movie ID 346961
# Processed movie ID 346537
# Processed movie ID 341605
# Processed movie ID 335455
# Processed movie ID 331182
# Processed movie ID 329818
# Processed movie ID 321493
# Processed movie ID 301049
# Processed movie ID 297530
# Processed movie ID 292953
# Processed movie ID 287809
# Processed movie ID 278266
# Processed movie ID 269236
# Processed movie ID 267328
# Processed movie ID 266779
# Processed movie ID 249532
# Processed movie ID 244028
# Processed movie ID 235924
# Processed movie ID 211615
# Processed movie ID 211438
# Processed movie ID 210539
# Processed movie ID 193904
# Processed movie ID 192708
# Processed movie ID 176270
# Processed movie ID 174696
# Processed movie ID 172035
# Processed movie ID 170367
# Processed movie ID 140566
# Processed movie ID 122247
# Processed movie ID 120924
# Processed movie ID 103395
# Processed movie ID 101333
# Processed movie ID 95742
# Processed movie ID 94026
# Processed movie ID 86559
# Processed movie ID 85462
# Processed movie ID 82892
# Processed movie ID 82681
# Processed movie ID 81765
# Processed movie ID 81228
# Processed movie ID 80589
# Processed movie ID 78447
# Processed movie ID 74797
# Processed movie ID 74007
# Processed movie ID 73157
# Processed movie ID 67504
# Processed movie ID 59810
# Processed movie ID 87408
# Processed movie ID 268396
# Processed movie ID 101715
# Processed movie ID 191005
# Processed movie ID 378184
# Processed movie ID 223767
# Processed movie ID 199387
# Processed movie ID 552833
# Processed movie ID 325518
# Processed movie ID 266371
# Processed movie ID 259123
# Processed movie ID 210506
# Processed movie ID 203138
# Processed movie ID 167289
# Processed movie ID 164178
# Processed movie ID 145599
# Processed movie ID 137858
# Processed movie ID 135478
# Processed movie ID 129892
# Processed movie ID 109647
# Processed movie ID 87238
# Processed movie ID 182865
# Processed movie ID 162981
# Processed movie ID 126251
# Processed movie ID 81657
# Processed movie ID 251206
# Processed movie ID 111643
# Processed movie ID 51410
# Processed movie ID 567180
# Processed movie ID 528026
# Processed movie ID 519567
# Processed movie ID 509520
# Processed movie ID 495772
# Processed movie ID 473122
# Processed movie ID 454754
# Processed movie ID 439766
# Processed movie ID 439129
# Processed movie ID 431234
# Processed movie ID 398313
# Processed movie ID 372914
# Processed movie ID 342769
# Processed movie ID 341598
# Processed movie ID 340303
# Processed movie ID 292540
# Processed movie ID 285250
# Processed movie ID 284002
# Processed movie ID 274558
# Processed movie ID 274387
# Processed movie ID 273939
# Processed movie ID 273736
# Processed movie ID 272085
# Processed movie ID 260485
# Processed movie ID 248881
# Processed movie ID 238959
# Processed movie ID 238067
# Processed movie ID 225312
# Processed movie ID 219686
# Processed movie ID 211620
# Processed movie ID 211616
# Processed movie ID 211439
# Processed movie ID 211401
# Processed movie ID 209913
# Processed movie ID 196894
# Processed movie ID 187815
# Processed movie ID 185335
# Processed movie ID 173939
# Processed movie ID 159186
# Processed movie ID 147272
# Processed movie ID 132131
# Processed movie ID 131659
# Processed movie ID 121077
# Processed movie ID 119038
# Processed movie ID 118405
# Processed movie ID 113374
# Processed movie ID 112441
# Processed movie ID 96802
# Processed movie ID 81644
# Processed movie ID 75446
# Processed movie ID 72301
# Processed movie ID 68011
# Processed movie ID 163429
# Processed movie ID 82646
# Processed movie ID 68246
# Processed movie ID 68049
# Processed movie ID 66779
# Processed movie ID 308779
# Processed movie ID 84553
# Processed movie ID 83934
# Processed movie ID 47755
# Processed movie ID 100454
# Processed movie ID 277548
# Processed movie ID 72003
# Processed movie ID 515773
# Processed movie ID 382122
# Processed movie ID 292790
# Processed movie ID 260614
# Processed movie ID 212193
# Processed movie ID 195698
# Processed movie ID 190667
# Processed movie ID 181045
# Processed movie ID 172336
# Processed movie ID 171376
# Processed movie ID 139712
# Processed movie ID 138061
# Processed movie ID 137562
# Processed movie ID 137008
# Processed movie ID 133108
# Processed movie ID 120459
# Processed movie ID 108360
# Processed movie ID 92237
# Processed movie ID 89312
# Processed movie ID 82117
# Processed movie ID 81378
# Processed movie ID 75757
# Processed movie ID 71621
# Processed movie ID 70869
# Processed movie ID 65691
# Processed movie ID 47750
# Processed movie ID 130758
# Processed movie ID 124991
# Processed movie ID 85028
# Processed movie ID 81798
# Processed movie ID 95642
# Processed movie ID 91311
# Processed movie ID 61794
# Processed movie ID 347090
# Processed movie ID 100875
# Processed movie ID 81658
# Processed movie ID 72845
# Processed movie ID 584615
# Processed movie ID 557126
# Processed movie ID 520224
# Processed movie ID 503210
# Processed movie ID 488783
# Processed movie ID 472721
# Processed movie ID 465743
# Processed movie ID 436664
# Processed movie ID 436118
# Processed movie ID 431238
# Processed movie ID 429537
# Processed movie ID 416634
# Processed movie ID 410675
# Processed movie ID 410536
# Processed movie ID 393760
# Processed movie ID 379773
# Processed movie ID 359348
# Processed movie ID 352790
# Processed movie ID 352724
# Processed movie ID 337818
# Processed movie ID 329677
# Processed movie ID 325266
# Processed movie ID 322682
# Processed movie ID 322503
# Processed movie ID 307378
# Processed movie ID 305003
# Processed movie ID 301021
# Processed movie ID 300608
# Processed movie ID 296273
# Processed movie ID 292155
# Processed movie ID 288905
# Processed movie ID 281253
# Processed movie ID 278496
# Processed movie ID 276383
# Processed movie ID 273298
# Processed movie ID 273144
# Processed movie ID 273131
# Processed movie ID 273121
# Processed movie ID 270812
# Processed movie ID 258855
# Processed movie ID 258267
# Processed movie ID 256922
# Processed movie ID 251183
# Processed movie ID 239729
# Processed movie ID 232036
# Processed movie ID 227215
# Processed movie ID 223974
# Processed movie ID 214873
# Processed movie ID 211618
# Processed movie ID 211020
# Processed movie ID 210926
# Processed movie ID 210729
# Processed movie ID 210545
# Processed movie ID 209710
# Processed movie ID 201284
# Processed movie ID 185712
# Processed movie ID 178514
# Processed movie ID 173273
# Processed movie ID 167271
# Processed movie ID 164168
# Processed movie ID 157127
# Processed movie ID 154766
# Processed movie ID 138080
# Processed movie ID 137365
# Processed movie ID 135685
# Processed movie ID 135476
# Processed movie ID 132912
# Processed movie ID 132687
# Processed movie ID 130979
# Processed movie ID 128544
# Processed movie ID 123602
# Processed movie ID 122140
# Processed movie ID 121839
# Processed movie ID 118094
# Processed movie ID 116732
# Processed movie ID 107606
# Processed movie ID 105542
# Processed movie ID 85307
# Processed movie ID 80048
# Processed movie ID 80039
# Processed movie ID 75672
# Processed movie ID 69612
# Processed movie ID 68197
# Processed movie ID 65289
# Processed movie ID 62078
# Processed movie ID 56740
# Processed movie ID 64130
# Processed movie ID 341600
# Processed movie ID 52931
# Processed movie ID 268392
# Processed movie ID 78556
# Processed movie ID 66109
# Processed movie ID 58031
# Processed movie ID 128499
# Processed movie ID 96064
# Processed movie ID 91324
# Processed movie ID 401352
# Processed movie ID 154082
# Processed movie ID 136805
# Processed movie ID 78443
# Processed movie ID 75760
# Processed movie ID 81660
# Processed movie ID 73350
# Processed movie ID 111662
# Processed movie ID 109233
# Processed movie ID 94910
# Processed movie ID 79458
# Processed movie ID 44120
# Processed movie ID 92127
# Processed movie ID 97659
# Processed movie ID 392768
# Processed movie ID 377567
# Processed movie ID 314841
# Processed movie ID 280556
# Processed movie ID 279009
# Processed movie ID 273001
# Processed movie ID 268952
# Processed movie ID 245514
# Processed movie ID 241370
# Processed movie ID 182867
# Processed movie ID 155098
# Processed movie ID 149756
# Processed movie ID 110406
# Processed movie ID 85709
# Processed movie ID 83780
# Processed movie ID 80467
# Processed movie ID 76098
# Processed movie ID 74891
# Processed movie ID 152413
# Processed movie ID 99393
# Processed movie ID 489791
# Processed movie ID 374805
# Processed movie ID 117876
# Processed movie ID 110129
# Processed movie ID 44213
# Processed movie ID 302618
# Processed movie ID 286485
# Processed movie ID 283835
# Processed movie ID 259125
# Processed movie ID 254966
# Processed movie ID 254962
# Processed movie ID 253514
# Processed movie ID 248646
# Processed movie ID 116859
# Processed movie ID 104224
# Processed movie ID 99776
# Processed movie ID 95264
# Processed movie ID 87031
# Processed movie ID 84550
# Processed movie ID 84402
# Processed movie ID 81266
# Processed movie ID 80997
# Processed movie ID 75918
# Processed movie ID 71740
# Processed movie ID 71438
# Processed movie ID 66611
# Processed movie ID 65307
# Processed movie ID 64529
# Processed movie ID 62853
# Processed movie ID 61719
# Processed movie ID 61657
# Processed movie ID 56425
# Processed movie ID 169237
# Processed movie ID 61629
# Processed movie ID 586636
# Processed movie ID 565661
# Processed movie ID 530142
# Processed movie ID 509095
# Processed movie ID 508072
# Processed movie ID 496434
# Processed movie ID 468301
# Processed movie ID 467161
# Processed movie ID 450027
# Processed movie ID 448051
# Processed movie ID 400330
# Processed movie ID 387559
# Processed movie ID 381647
# Processed movie ID 370484
# Processed movie ID 351796
# Processed movie ID 346983
# Processed movie ID 346916
# Processed movie ID 331723
# Processed movie ID 326751
# Processed movie ID 326655
# Processed movie ID 325909
# Processed movie ID 325777
# Processed movie ID 322241
# Processed movie ID 311613
# Processed movie ID 305065
# Processed movie ID 303025
# Processed movie ID 300250
# Processed movie ID 298460
# Processed movie ID 275525
# Processed movie ID 275161
# Processed movie ID 272792
# Processed movie ID 270604
# Processed movie ID 262162
# Processed movie ID 259540
# Processed movie ID 245909
# Processed movie ID 242836
# Processed movie ID 241025
# Processed movie ID 240863
# Processed movie ID 235537
# Processed movie ID 226207
# Processed movie ID 220363
# Processed movie ID 218861
# Processed movie ID 218843
# Processed movie ID 214102
# Processed movie ID 205760
# Processed movie ID 202947
# Processed movie ID 194099
# Processed movie ID 191586
# Processed movie ID 184502
# Processed movie ID 184127
# Processed movie ID 180318
# Processed movie ID 179389
# Processed movie ID 167671
# Processed movie ID 165481
# Processed movie ID 165370
# Processed movie ID 163380
# Processed movie ID 160669
# Processed movie ID 160008
# Processed movie ID 157126
# Processed movie ID 147485
# Processed movie ID 145869
# Processed movie ID 144161
# Processed movie ID 133186
# Processed movie ID 129321
# Processed movie ID 127791
# Processed movie ID 121140
# Processed movie ID 119453
# Processed movie ID 115400
# Processed movie ID 113038
# Processed movie ID 112963
# Processed movie ID 108337
# Processed movie ID 105964
# Processed movie ID 102652
# Processed movie ID 100829
# Processed movie ID 99777
# Processed movie ID 99495
# Processed movie ID 97245
# Processed movie ID 93556
# Processed movie ID 91325
# Processed movie ID 85096
# Processed movie ID 84335
# Processed movie ID 84138
# Processed movie ID 80202
# Processed movie ID 78243
# Processed movie ID 77090
# Processed movie ID 77028
# Processed movie ID 74102
# Processed movie ID 71816
# Processed movie ID 70383
# Processed movie ID 68438
# Processed movie ID 63457
# Processed movie ID 60019
# Processed movie ID 56443
# Processed movie ID 52014
# Processed movie ID 97008
# Processed movie ID 99534
# Processed movie ID 120261
# Processed movie ID 262893
# Processed movie ID 261110
# Processed movie ID 222621
# Processed movie ID 88842
# Processed movie ID 69008
# Processed movie ID 67299
# Processed movie ID 276633
# Processed movie ID 82076
# Processed movie ID 151421
# Processed movie ID 120872
# Processed movie ID 531522
# Processed movie ID 342779
# Processed movie ID 234165
# Processed movie ID 226614
# Processed movie ID 142402
# Processed movie ID 140659
# Processed movie ID 118288
# Processed movie ID 102693
# Processed movie ID 98014
# Processed movie ID 88612
# Processed movie ID 85466
# Processed movie ID 81954
# Processed movie ID 81516
# Processed movie ID 81241
# Processed movie ID 74460
# Processed movie ID 70871
# Processed movie ID 66154
# Processed movie ID 54431
# Processed movie ID 265004
# Processed movie ID 145877
# Processed movie ID 87737
# Processed movie ID 270408
# Processed movie ID 240618
# Processed movie ID 81928
# Processed movie ID 81921
# Processed movie ID 70905
# Processed movie ID 127689
# Processed movie ID 582738
# Processed movie ID 484637
# Processed movie ID 426644
# Processed movie ID 328571
# Processed movie ID 324561
# Processed movie ID 305171
# Processed movie ID 281229
# Processed movie ID 275165
# Processed movie ID 272714
# Processed movie ID 272710
# Processed movie ID 272468
# Processed movie ID 270884
# Processed movie ID 262320
# Processed movie ID 229804
# Processed movie ID 225498
# Processed movie ID 217087
# Processed movie ID 211440
# Processed movie ID 209704
# Processed movie ID 176812
# Processed movie ID 151523
# Processed movie ID 150136
# Processed movie ID 142131
# Processed movie ID 123166
# Processed movie ID 123101
# Processed movie ID 116004
# Processed movie ID 113328
# Processed movie ID 86528
# Processed movie ID 86375
# Processed movie ID 84585
# Processed movie ID 84531
# Processed movie ID 83916
# Processed movie ID 83725
# Processed movie ID 81013
# Processed movie ID 80390
# Processed movie ID 78022
# Processed movie ID 77603
# Processed movie ID 70072
# Processed movie ID 69325
# Processed movie ID 65763
# Processed movie ID 60829
# Processed movie ID 57462
# Processed movie ID 95040
# Processed movie ID 288250
# Processed movie ID 167304
# Processed movie ID 163449
# Processed movie ID 120498
# Processed movie ID 106187
# Processed movie ID 75270
# Processed movie ID 72588
# Processed movie ID 83735
# Processed movie ID 289545
# Processed movie ID 224352
# Processed movie ID 134327
# Processed movie ID 104826
# Processed movie ID 82840
# Processed movie ID 133682
# Processed movie ID 127818
# Processed movie ID 102060
# ...
# Processed movie ID 401342
# Processed movie ID 395681
# Processed movie ID 354373
# Processed movie ID 352545
# Processed movie ID 334749
# Processed movie ID 334209
# Processed movie ID 332279
# Processed movie ID 331171
# Processed movie ID 326647
# Processed movie ID 325906
# Processed movie ID 307769
# Processed movie ID 305514
# Processed movie ID 297844
# Processed movie ID 296127
# Processed movie ID 285067
# Processed movie ID 279572
# Processed movie ID 278436
# Processed movie ID 273593
# Processed movie ID 263009
# Processed movie ID 259539
# Processed movie ID 259438
# Processed movie ID 258811
# Processed movie ID 255754
# Processed movie ID 243132
# Processed movie ID 231994
# Processed movie ID 226985
# Processed movie ID 222465
# Processed movie ID 218065
# Processed movie ID 212192
# Processed movie ID 210516
# Processed movie ID 208472
# Processed movie ID 202629
# Processed movie ID 188073
# Processed movie ID 177354
# Processed movie ID 177258
# Processed movie ID 166169
# Processed movie ID 163316
# Processed movie ID 159825
# Processed movie ID 159522
# Processed movie ID 154860
# Processed movie ID 154770
# Processed movie ID 152226
# Processed movie ID 147841
# Processed movie ID 146038
# Processed movie ID 145196
# Processed movie ID 143366
# Processed movie ID 142581
# Processed movie ID 140838
# Processed movie ID 138303
# Processed movie ID 138294
# Processed movie ID 138292
# Processed movie ID 136074
# Processed movie ID 135205
# Processed movie ID 133734
# Processed movie ID 132887
# Processed movie ID 129113
# Processed movie ID 127929
# Processed movie ID 121127
# Processed movie ID 118976
# Processed movie ID 118723
# Processed movie ID 113311
# Processed movie ID 108540
# Processed movie ID 108207
# Processed movie ID 106474
# Processed movie ID 105677
# Processed movie ID 103829
# Processed movie ID 102596
# Processed movie ID 100813
# Processed movie ID 99395
# Processed movie ID 98068
# Processed movie ID 97572
# Processed movie ID 96090
# Processed movie ID 91972
# Processed movie ID 91319
# Processed movie ID 89596
# Processed movie ID 87383
# Processed movie ID 84307
# Processed movie ID 84186
# Processed movie ID 81634
# Processed movie ID 187263
# Processed movie ID 397739
# Processed movie ID 168890
# Processed movie ID 348090
# Processed movie ID 273508
# Processed movie ID 106184
# Processed movie ID 182349
# Processed movie ID 333493
# Processed movie ID 282726
# Processed movie ID 182534
# Processed movie ID 150030
# Processed movie ID 98560
# Processed movie ID 401479
# Processed movie ID 115251
# Processed movie ID 118278
# Processed movie ID 476676
# Processed movie ID 366762
# Processed movie ID 303682
# Processed movie ID 292600
# Processed movie ID 283187
# Processed movie ID 276328
# Processed movie ID 255650
# Processed movie ID 228238
# Processed movie ID 218348
# Processed movie ID 203893
# Processed movie ID 182970
# Processed movie ID 181274
# Processed movie ID 168878
# Processed movie ID 168873
# Processed movie ID 167957
# Processed movie ID 147165
# Processed movie ID 121096
# Processed movie ID 116876
# Processed movie ID 116771
# Processed movie ID 115033
# Processed movie ID 111240
# Processed movie ID 97684
# Processed movie ID 289442
# Processed movie ID 298776
# Processed movie ID 149234
# Processed movie ID 295250
# Processed movie ID 286176
# Processed movie ID 284731
# Processed movie ID 281664
# Processed movie ID 238670
# Processed movie ID 230090
# Processed movie ID 215258
# Processed movie ID 206883
# Processed movie ID 171230
# Processed movie ID 168253
# Processed movie ID 142293
# Processed movie ID 138154
# Processed movie ID 132059
# Processed movie ID 127708
# Processed movie ID 126785
# Processed movie ID 110541
# Processed movie ID 519960
# Processed movie ID 495717
# Processed movie ID 424993
# Processed movie ID 416926
# Processed movie ID 397134
# Processed movie ID 371888
# Processed movie ID 364296
# Processed movie ID 288809
# Processed movie ID 279673
# Processed movie ID 273759
# Processed movie ID 273725
# Processed movie ID 245963
# Processed movie ID 242552
# Processed movie ID 236816
# Processed movie ID 227281
# Processed movie ID 217899
# Processed movie ID 213476
# Processed movie ID 206397
# Processed movie ID 203385
# Processed movie ID 202437
# Processed movie ID 197048
# Processed movie ID 189939
# Processed movie ID 178980
# Processed movie ID 167437
# Processed movie ID 152622
# Processed movie ID 150908
# Processed movie ID 149764
# Processed movie ID 142362
# Processed movie ID 142315
# Processed movie ID 137312
# Processed movie ID 123943
# Processed movie ID 122280
# Processed movie ID 109695
# Processed movie ID 109440
# Processed movie ID 105591
# Processed movie ID 133082
# Processed movie ID 168042
# Processed movie ID 143602
# Processed movie ID 413469
# Processed movie ID 306989
# Processed movie ID 267919
# Processed movie ID 176990
# Processed movie ID 172020
# Processed movie ID 132097
# Processed movie ID 123083
# Processed movie ID 112825
# Processed movie ID 87426
# Processed movie ID 330793
# Processed movie ID 293188
# Processed movie ID 184701
# Processed movie ID 140853
# Processed movie ID 301122
# Processed movie ID 255921
# Processed movie ID 229890
# Processed movie ID 228086
# Processed movie ID 223605
# Processed movie ID 192196
# Processed movie ID 179012
# Processed movie ID 155029
# Processed movie ID 120764
# Processed movie ID 102111
# Processed movie ID 378632
# Processed movie ID 365512
# Processed movie ID 290669
# Processed movie ID 191379
# Processed movie ID 74194
# Processed movie ID 509137
# Processed movie ID 469702
# Processed movie ID 367346
# Processed movie ID 304037
# Processed movie ID 291278
# Processed movie ID 278024
# Processed movie ID 272800
# Processed movie ID 271050
# Processed movie ID 270630
# Processed movie ID 250624
# Processed movie ID 232097
# Processed movie ID 201642
# Processed movie ID 192179
# Processed movie ID 187566
# Processed movie ID 186592
# Processed movie ID 160798
# Processed movie ID 100082
# Processed movie ID 94471
# Processed movie ID 217362
# Processed movie ID 186062
# Processed movie ID 433500
# Processed movie ID 259124
# Processed movie ID 253245
# Processed movie ID 173718
# Processed movie ID 160758
# Processed movie ID 283543
# Processed movie ID 153976
# Processed movie ID 150061
# Processed movie ID 544983
# Processed movie ID 468083
# Processed movie ID 410653
# Processed movie ID 351743
# Processed movie ID 297461
# Processed movie ID 288505
# Processed movie ID 275570
# Processed movie ID 260622
# Processed movie ID 232291
# Processed movie ID 222391
# Processed movie ID 167401
# Processed movie ID 160560
# Processed movie ID 147484
# Processed movie ID 141899
# Processed movie ID 141618
# Processed movie ID 136549
# Processed movie ID 132066
# Processed movie ID 119723
# Processed movie ID 103710
# Processed movie ID 102156
# Processed movie ID 262267
# Processed movie ID 339503
# Processed movie ID 278359
# Processed movie ID 275950
# Processed movie ID 275203
# Processed movie ID 228080
# Processed movie ID 220850
# Processed movie ID 138186
# Processed movie ID 309955
# Processed movie ID 152869
# Processed movie ID 95757
# Processed movie ID 513918
# Processed movie ID 405547
# Processed movie ID 383148
# Processed movie ID 305037
# Processed movie ID 288226
# Processed movie ID 279948
# Processed movie ID 270603
# Processed movie ID 269786
# Processed movie ID 259542
# Processed movie ID 252567
# Processed movie ID 223106
# Processed movie ID 222662
# Processed movie ID 216749
# Processed movie ID 211652
# Processed movie ID 176646
# Processed movie ID 158341
# Processed movie ID 140839
# Processed movie ID 134644
# Processed movie ID 132080
# Processed movie ID 123224
# Processed movie ID 116330
# Processed movie ID 105892
# Processed movie ID 101723
# Processed movie ID 64932
# Processed movie ID 399800
# Processed movie ID 177570
# Processed movie ID 152827
# Processed movie ID 74114
# Processed movie ID 72377
# Processed movie ID 55000
# Processed movie ID 229951
# Processed movie ID 142377
# Processed movie ID 68721
# Processed movie ID 76338
# Processed movie ID 106646
# Processed movie ID 49047
# Processed movie ID 49521
# Processed movie ID 109445
# Processed movie ID 64686
# Processed movie ID 158015
# Processed movie ID 49524
# Processed movie ID 57158
# Processed movie ID 54138
# Processed movie ID 62211
# Processed movie ID 101299
# Processed movie ID 93456
# Processed movie ID 138843
# Processed movie ID 75612
# Processed movie ID 109439
# Processed movie ID 156711
# Processed movie ID 109451
# Processed movie ID 76617
# Processed movie ID 107846
# Processed movie ID 68724
# Processed movie ID 70074
# Processed movie ID 87421
# Processed movie ID 86331
# Processed movie ID 136795
# Processed movie ID 68726
# Processed movie ID 134411
# Processed movie ID 75656
# Processed movie ID 134374
# Processed movie ID 76203
# Processed movie ID 123553
# Processed movie ID 4258
# Processed movie ID 49519
# Processed movie ID 136418
# Processed movie ID 60304
# Processed movie ID 152601
# Processed movie ID 76640
# Processed movie ID 47964
# Processed movie ID 76285
# Processed movie ID 80274
# Processed movie ID 109424
# Processed movie ID 193756
# Processed movie ID 64682
# Processed movie ID 7131
# Processed movie ID 72559
# Processed movie ID 2280
# Processed movie ID 146216
# Processed movie ID 119283
# Processed movie ID 77950
# Processed movie ID 136400
# Processed movie ID 59859
# Processed movie ID 138832
# Processed movie ID 96721
# Processed movie ID 72190
# Processed movie ID 204082
# Processed movie ID 82700
# Processed movie ID 146233
# Processed movie ID 91586
# Processed movie ID 122906
# Processed movie ID 116711
# Processed movie ID 151960
# Processed movie ID 117263
# Processed movie ID 98567
# Processed movie ID 103663
# Processed movie ID 133805
# Processed movie ID 157386
# Processed movie ID 171424
# Processed movie ID 98357
# Processed movie ID 109431
# Processed movie ID 68728
# Processed movie ID 142061
# Processed movie ID 82654
# Processed movie ID 76544
# Processed movie ID 122126
# Processed movie ID 109428
# Processed movie ID 211387
# Processed movie ID 82682
# Processed movie ID 117251
# Processed movie ID 97367
# Processed movie ID 77931
# Processed movie ID 87818
# Processed movie ID 138697
# Processed movie ID 81005
# Processed movie ID 107985
# Processed movie ID 103731
# Processed movie ID 57201
# Processed movie ID 168672
# Processed movie ID 58244
# Processed movie ID 152532
# Processed movie ID 110420
# Processed movie ID 109443
# Processed movie ID 132232
# Processed movie ID 183011
# Processed movie ID 167032
# Processed movie ID 132344
# Processed movie ID 9352
# Processed movie ID 145135
# Processed movie ID 112205
# Processed movie ID 121734
# Processed movie ID 207768
# Processed movie ID 72710
# Processed movie ID 83899
# Processed movie ID 180894
# Processed movie ID 87516
# Processed movie ID 158011
# Processed movie ID 198375
# Processed movie ID 109418
# Processed movie ID 109410
# Processed movie ID 87567
# Processed movie ID 109491
# Processed movie ID 222230
# Processed movie ID 175774
# Processed movie ID 175574
# Processed movie ID 167575
# Processed movie ID 174772
# Processed movie ID 146227
# Processed movie ID 116745
# Processed movie ID 86825
# Processed movie ID 122081
# Processed movie ID 109414
# Processed movie ID 156717
# Processed movie ID 220289
# Processed movie ID 77951
# Processed movie ID 109091
# Processed movie ID 86829
# Processed movie ID 11976
# Processed movie ID 102780
# Processed movie ID 160588
# Processed movie ID 146238
# Processed movie ID 172803
# Processed movie ID 106747
# Processed movie ID 102362
# Processed movie ID 199373
# Processed movie ID 127517
# Processed movie ID 77987
# Processed movie ID 192145
# Processed movie ID 174321
# Processed movie ID 169813
# Processed movie ID 9022
# Processed movie ID 147773
# Processed movie ID 179144
# Processed movie ID 152747
# Processed movie ID 60281
# Processed movie ID 196254
# Processed movie ID 150202
# Processed movie ID 107811
# Processed movie ID 251749
# Processed movie ID 146381
# Processed movie ID 160070
# Processed movie ID 166076
# Processed movie ID 172391
# Processed movie ID 157354
# Processed movie ID 152737
# Processed movie ID 140823
# Processed movie ID 68727
# Processed movie ID 11123
# Processed movie ID 111473
# Processed movie ID 209247
# Processed movie ID 97370
# Processed movie ID 129670
# Processed movie ID 152780
# Processed movie ID 109421
# Processed movie ID 121986
# Processed movie ID 124459
# Processed movie ID 175168
# Processed movie ID 111190
# Processed movie ID 121824
# Processed movie ID 169209
# Processed movie ID 130150
# Processed movie ID 179826
# Processed movie ID 68179
# Processed movie ID 106021
# Processed movie ID 177888
# Processed movie ID 164457
# Processed movie ID 167581
# Processed movie ID 121674
# Processed movie ID 112949
# Processed movie ID 166666
# Processed movie ID 77234
# Processed movie ID 111969
# Processed movie ID 203833
# Processed movie ID 44865
# Processed movie ID 168903
# Processed movie ID 164558
# Processed movie ID 172533
# Processed movie ID 123109
# Processed movie ID 205220
# Processed movie ID 10199
# Processed movie ID 96936
# Processed movie ID 178682
# Processed movie ID 185460
# Processed movie ID 70667
# Processed movie ID 208134
# Processed movie ID 64246
# Processed movie ID 97512
# Processed movie ID 159117
# Processed movie ID 158907
# Processed movie ID 190847
# Processed movie ID 205724
# Processed movie ID 209263
# Processed movie ID 126250
# Processed movie ID 81446
# Processed movie ID 175528
# Processed movie ID 227679
# Processed movie ID 156700
# Processed movie ID 146304
# Processed movie ID 113148
# Processed movie ID 181330
# Processed movie ID 87496
# Processed movie ID 104755
# Processed movie ID 100271
# Processed movie ID 227707
# Processed movie ID 77663
# Processed movie ID 115283
# Processed movie ID 157360
# Processed movie ID 121826
# Processed movie ID 144789
# Processed movie ID 93828
# Processed movie ID 184219
# Processed movie ID 110410
# Processed movie ID 192136
# Processed movie ID 219572
# Processed movie ID 83186
# Processed movie ID 152748
# Processed movie ID 152599
# Processed movie ID 91745
# Processed movie ID 135531
# Processed movie ID 219318
# Processed movie ID 178809
# Processed movie ID 144340
# Processed movie ID 151933
# Processed movie ID 165213
# Processed movie ID 87499
# Processed movie ID 115782
# Processed movie ID 188166
# Processed movie ID 20043
# Processed movie ID 146239
# Processed movie ID 200481
# Processed movie ID 191720
# Processed movie ID 162145
# Processed movie ID 64807
# Processed movie ID 77495
# Processed movie ID 121875
# Processed movie ID 173185
# Processed movie ID 149085
# Processed movie ID 159014
# Processed movie ID 169934
# Processed movie ID 188538
# Processed movie ID 157115
# Processed movie ID 216769
# Processed movie ID 205022
# Processed movie ID 169219
# Processed movie ID 70706
# Processed movie ID 230222
# Processed movie ID 183662
# Processed movie ID 150117
# Processed movie ID 184352
# Processed movie ID 174316
# Processed movie ID 226672
# Processed movie ID 230896
# Processed movie ID 217923
# Processed movie ID 122369
# Processed movie ID 115348
# Processed movie ID 146223
# Processed movie ID 110160
# Processed movie ID 232175
# Processed movie ID 159092
# Processed movie ID 209276
# Processed movie ID 174343
# Processed movie ID 172828
# Processed movie ID 195269
# Processed movie ID 132363
# Processed movie ID 198210
# Processed movie ID 72525
# Processed movie ID 186992
# Processed movie ID 146203
# Processed movie ID 143049
# Processed movie ID 165864
# Processed movie ID 162215
# Processed movie ID 158990
# Processed movie ID 152792
# Processed movie ID 251783
# Processed movie ID 149910
# Processed movie ID 257874
# Processed movie ID 134350
# Processed movie ID 128216
# Processed movie ID 180948
# Processed movie ID 157375
# Processed movie ID 205321
# Processed movie ID 121677
# Processed movie ID 153738
# Processed movie ID 176570
# Processed movie ID 110398
# Processed movie ID 102001
# Processed movie ID 103758
# Processed movie ID 210908
# Processed movie ID 200085
# Processed movie ID 174675
# Processed movie ID 21634
# Processed movie ID 72890
# Processed movie ID 210047
# Processed movie ID 204349
# Processed movie ID 18392
# Processed movie ID 238628
# Processed movie ID 129139
# Processed movie ID 129112
# Processed movie ID 118289
# Processed movie ID 157370
# Processed movie ID 193613
# Processed movie ID 136403
# Processed movie ID 114606
# Processed movie ID 192132
# Processed movie ID 195544
# Processed movie ID 77805
# Processed movie ID 123103
# Processed movie ID 152584
# Processed movie ID 200713
# Processed movie ID 152259
# Processed movie ID 183836
# Processed movie ID 2161
# Processed movie ID 166271
# Processed movie ID 40171
# Processed movie ID 84204
# Processed movie ID 139519
# Processed movie ID 15049
# Processed movie ID 154030

# %%
# MAPPING THE MOVIES TO THEIR RESPECTIVE GENRES USING GENRE IDS
 # To evaluate genre_ids strings as Python lists

# Load the enriched dataset
file_path = 'enriched_tmdb_movies.csv'
data = pd.read_csv(file_path)

# Predefined TMDB Genre Mapping
genre_mapping = {
    28: "Action",
    12: "Adventure",
    16: "Animation",
    35: "Comedy",
    80: "Crime",
    99: "Documentary",
    18: "Drama",
    10751: "Family",
    14: "Fantasy",
    36: "History",
    27: "Horror",
    10402: "Music",
    9648: "Mystery",
    10749: "Romance",
    878: "Science Fiction",
    10770: "TV Movie",
    53: "Thriller",
    10752: "War",
    37: "Western"
}

# Function to map genre IDs to names
def map_genres(genre_ids_str):
    try:
        genre_ids = ast.literal_eval(genre_ids_str)  # Convert string to list
        return ', '.join([genre_mapping.get(genre_id, "Unknown") for genre_id in genre_ids])
    except Exception as e:
        return "Unknown"

# Apply the mapping to the genre_ids column
data['Genres'] = data['genre_ids'].apply(map_genres)

# Save the updated dataset
output_file = 'final_tmdb.xlsx'
data.to_excel(output_file, index=False)

print(f"Updated dataset with genres saved to {output_file}")
# Out:
# Updated dataset with genres saved to final_tmdb.xlsx

# %%
tmdb_data = pd.read_excel('final_tmdb.xlsx')

# %%
# Merge with the tmdb budget dataset on 'id'
budget_data = pd.read_csv('budget_data.csv')
tmdb_data = pd.merge(tmdb_data, budget_data, on='id', how='left')

# %%
tmdb_data.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           3      [16, 35, 10751]    862                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Toy Story      28.005   1995-11-22
#
#                                           title  vote_average  vote_count  \
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Toy Story           7.9       10174
#
#                                             Overview    Revenue  \
# 0  Harry, Ron and Hermione walk away from their l...  954305868
# 1  As the son of a Viking leader on the cusp of m...  494879471
# 2  With the world now aware of his dual life as t...  623933331
# 3  Led by Woody, Andy's toys live happily in his ...  394436586
# 4  Led by Woody, Andy's toys live happily in his ...  394436586
#
#                                             Top Cast       Director  \
# 0  Daniel Radcliffe, Emma Watson, Rupert Grint, T...    David Yates
# 1  Jay Baruchel, Gerard Butler, Craig Ferguson, A...   Dean DeBlois
# 2  Robert Downey Jr., Gwyneth Paltrow, Don Cheadl...    Jon Favreau
# 3  Tom Hanks, Tim Allen, Don Rickles, Jim Varney,...  John Lasseter
# 4  Tom Hanks, Tim Allen, Don Rickles, Jim Varney,...  John Lasseter
#
#                                   Genres       Budget
# 0             Adventure, Fantasy, Family  250000000.0
# 1  Fantasy, Adventure, Animation, Family  165000000.0
# 2     Adventure, Action, Science Fiction  200000000.0
# 3              Animation, Comedy, Family   30000000.0
# 4              Animation, Comedy, Family   30000000.0

# %%
tmdb_data.shape
# Out:
# (28605, 16)

# %% [markdown]
# #### IMDB

# %%
file = "im.db"
con =sqlite3.connect(file)

# %%
cur = con.cursor()

# %%
cur.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cur.fetchall()
print(tables)
# Out:
# [('movie_basics',), ('directors',), ('known_for',), ('movie_akas',), ('movie_ratings',), ('persons',), ('principals',), ('writers',)]

# %%
df = pd.read_sql("SELECT * FROM movie_basics", con)
df.head()
# Out:
#     movie_id                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
df2 = pd.read_sql("SELECT * FROM movie_akas", con)
df2.head()
# Out:
#     movie_id  ordering                                    title region  \
# 0  tt0369610        10                            Джурасик свят     BG
# 1  tt0369610        11                        Jurashikku warudo     JP
# 2  tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3  tt0369610        13                  O Mundo dos Dinossauros     BR
# 4  tt0369610        14                           Jurassic World     FR
#
#   language        types   attributes  is_original_title
# 0       bg         None         None                0.0
# 1     None  imdbDisplay         None                0.0
# 2     None  imdbDisplay         None                0.0
# 3     None         None  short title                0.0
# 4     None  imdbDisplay         None                0.0

# %%
df.shape
# Out:
# (146144, 6)

# %% [markdown]
# ##**DATA PREPARATION**

# %% [markdown]
# This will be handled through:
#
# *   Combining tables from different databases
# *   Handling Duplicates: Ensuring there are no repeated records
# *   Handling Missing Data:Fill in or remove incomplete data points, such as missing report status.
# *   Exploratory Data Analysis (EDA)

# %% [markdown]
# #### **MERGING TMDB AND IMDB DATA**

# %%
# Load the TMDb and IMDb data
imdb_data = df

# Normalize title columns by converting to lowercase and trimming whitespace
tmdb_data['title_normalized'] = tmdb_data['title'].str.lower().str.strip()
imdb_data['primary_title_normalized'] = imdb_data['primary_title'].str.lower().str.strip()

# Check for common titles
common_titles = set(tmdb_data['title_normalized']).intersection(set(imdb_data['primary_title_normalized']))

# Count the number of movies in both datasets
common_count = len(common_titles)
print(f"Number of common movies between TMDb and IMDb based on titles: {common_count}")
# Out:
# Number of common movies between TMDb and IMDb based on titles: 15369

# %%
tmdb_common = tmdb_data[tmdb_data['title_normalized'].isin(common_titles)].sort_values(by='title')
imdb_common = imdb_data[imdb_data['primary_title_normalized'].isin(common_titles)].sort_values(by='primary_title')

# %%
# Load the TMDb and IMDb data and remove duplicated
tmdb_data = tmdb_common
imdb_data = imdb_common
tmdb_data = tmdb_data.drop_duplicates(subset=['title_normalized'])
imdb_data = imdb_data.drop_duplicates(subset=['primary_title_normalized'])

# Normalizing title columns by converting to lowercase and trimming whitespace
tmdb_data['title_normalized'] = tmdb_data['title'].str.lower().str.strip()
imdb_data['primary_title_normalized'] = imdb_data['primary_title'].str.lower().str.strip()

# Inner join on normalized titles
merged_data = pd.merge(
    imdb_data[['primary_title', 'start_year', 'runtime_minutes', 'genres', 'primary_title_normalized']],
    tmdb_data[['title', 'vote_average', 'vote_count', 'Revenue', 'Top Cast', 'Director', 'Genres', 'title_normalized', 'Budget','popularity']],
    left_on='primary_title_normalized',
    right_on='title_normalized',
    how='inner'
)

# Desired columns in the result
merged_data = merged_data[[
    'primary_title', 'start_year', 'runtime_minutes', 'genres', 'vote_average',
    'vote_count', 'Top Cast', 'Director', 'popularity', 'Budget', 'Revenue'
]]

# Save the merged dataset to a file
merged_data.to_csv('merged_movies.csv', index=False)

print("Merged dataset saved successfully!")
# Out:
# <ipython-input-235-1831bf5d6eac>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_data['primary_title_normalized'] = imdb_data['primary_title'].str.lower().str.strip()
# Merged dataset saved successfully!
